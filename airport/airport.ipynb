# %%
#import plotly as py
#py.tools.set_credentials_file(username='RohanKittu', api_key='vck4ZMdiSI8qzfUgRymk')
#from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#import plotly.plotly as pl
#import plotly.graph_objs as go
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mpld3

# %%
data_air=pd.read_csv("Airports2.csv")
data_air.head(5)
# Out:
#   Origin_airport Destination_airport    Origin_city Destination_city  \
# 0            MHK                 AMW  Manhattan, KS         Ames, IA
# 1            EUG                 RDM     Eugene, OR         Bend, OR
# 2            EUG                 RDM     Eugene, OR         Bend, OR
# 3            EUG                 RDM     Eugene, OR         Bend, OR
# 4            MFR                 RDM    Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long  \
# 0                   86219        39.140999        -96.670799
# 1                   76034        44.124599       -123.211998
# 2                   76034        44.124599       -123.211998
# 3                   76034        44.124599       -123.211998
# 4                   76034        42.374199       -122.873001
#
#    Dest_airport_lat  Dest_airport_long
# 0               NaN                NaN
# 1         44.254101        -121.150001
# 2         44.254101        -121.150001
# 3         44.254101        -121.150001
# 4         44.254101        -121.150001

# %%
data_air.describe()
# Out:
#          Passengers         Seats       Flights      Distance  \
# count  3.606803e+06  3.606803e+06  3.606803e+06  3.606803e+06
# mean   2.688910e+03  4.048297e+03  3.722890e+01  6.973190e+02
# std    4.347617e+03  6.200871e+03  4.961970e+01  6.044165e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.090000e+02  1.560000e+02  2.000000e+00  2.730000e+02
# 50%    1.118000e+03  1.998000e+03  2.500000e+01  5.190000e+02
# 75%    3.503000e+03  5.370000e+03  5.500000e+01  9.270000e+02
# max    8.959700e+04  1.470620e+05  1.128000e+03  5.095000e+03
#
#        Origin_population  Destination_population  Org_airport_lat  \
# count       3.606803e+06            3.606803e+06     3.599849e+06
# mean        5.871502e+06            5.897982e+06     3.775029e+01
# std         7.858062e+06            7.906127e+06     5.765453e+00
# min         1.300500e+04            1.288700e+04     1.972140e+01
# 25%         1.030597e+06            1.025470e+06     3.363670e+01
# 50%         2.400193e+06            2.400193e+06     3.885210e+01
# 75%         8.613622e+06            8.635706e+06     4.173260e+01
# max         3.813959e+07            3.813959e+07     6.483750e+01
#
#        Org_airport_long  Dest_airport_lat  Dest_airport_long
# count      3.599849e+06      3.599996e+06       3.599996e+06
# mean      -9.186178e+01      3.774091e+01      -9.183433e+01
# std        1.653773e+01      5.736556e+00       1.647228e+01
# min       -1.579220e+02      1.972140e+01      -1.579220e+02
# 25%       -9.703800e+01      3.363670e+01      -9.703800e+01
# 50%       -8.775240e+01      3.885210e+01      -8.775240e+01
# 75%       -8.029060e+01      4.173260e+01      -8.029060e+01
# max       -6.882810e+01      6.483750e+01      -6.882810e+01

# %%
data_air_no_na=data_air.dropna()

# %%
#info is the function to see the structure of the pandas data frame.
data_air_no_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3594452 entries, 1 to 3606801
# Data columns (total 15 columns):
# Origin_airport            object
# Destination_airport       object
# Origin_city               object
# Destination_city          object
# Passengers                int64
# Seats                     int64
# Flights                   int64
# Distance                  int64
# Fly_date                  object
# Origin_population         int64
# Destination_population    int64
# Org_airport_lat           float64
# Org_airport_long          float64
# Dest_airport_lat          float64
# Dest_airport_long         float64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 438.8+ MB

# %%
'''
#plotting box plot by plotly
   y=data_air_no_na["Passengers"]
trace1 = go.Box(
    y=data_air_no_na["Distance"]
)
data = [trace0, trace1]
pl.iplot(data)
#conclusion the plotly is working but the graph is not showing for long time and plot is very slow.
'''
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~RohanKittu/4.embed" height="525px" width="100%"></iframe>

# %%
#The box plot by matplotlib
# basic plot
plt.title('The box plot of all integer type variable ')
data_numeric=data_air_no_na[["Passengers","Seats","Flights","Distance","Origin_population","Destination_population"]]
fig, ax = plt.subplots()
ax.boxplot(data_numeric)
figure=fig
#mpld3.display(figure)
plt.show()

# %%
#data_air_no_na.Origin_airport.unique()
data_air_no_na["Origin_city"].value_counts()

# %%
data_air_no_na["Destination_city"].value_counts()
# Out:
# Chicago, IL           187868
# Atlanta, GA           132846
# Dallas, TX            126229
# New York, NY          108638
# Detroit, MI           106621
# Houston, TX           105640
# Minneapolis, MN        98547
# Washington, DC         94298
# Charlotte, NC          85065
# Los Angeles, CA        84060
# Philadelphia, PA       82504
# Newark, NJ             82352
# St. Louis, MO          77174
# Phoenix, AZ            70487
# Memphis, TN            69873
# Pittsburgh, PA         69717
# Orlando, FL            64868
# Cincinnati, OH         60811
# Las Vegas, NV          60624
# San Francisco, CA      57185
# Boston, MA             56360
# Cleveland, OH          56212
# Seattle, WA            55235
# Baltimore, MD          47988
# Miami, FL              47778
# Salt Lake City, UT     45584
# Indianapolis, IN       44617
# Tampa, FL              40401
# Kansas City, MO        39189
# Nashville, TN          35390
#                        ...
# Ardmore, OK               27
# Blytheville, AR           25
# Mountain Home, ID         24
# Warrensburg, MO           22
# Logan, UT                 21
# Carbondale, IL            20
# Jackson, MI               20
# St. Joseph, MO            19
# New Iberia, LA            16
# Goldsboro, NC             11
# Salinas, CA               10
# Sandusky, OH              10
# Peru, IN                   9
# Crossville, TN             9
# Los Alamos, NM             6
# Jefferson City, MO         6
# Frankfort, KY              6
# Napa, CA                   6
# Lawrence, KS               5
# Bremerton, WA              4
# Lakeland, FL               4
# Auburn, AL                 4
# Uvalde, TX                 3
# Altus, OK                  3
# Bishop, CA                 3
# Easton, MD                 2
# Wheeling, WV               1
# Poughkeepsie, NY           1
# Racine, WI                 1
# Madera, CA                 1
# Name: Destination_city, Length: 399, dtype: int64

# %%
#plotting the correlation matrix
corr = data_air_no_na.corr()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col0 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col1 {
#             background-color:  #023f64;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col2 {
#             background-color:  #04629a;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col3 {
#             background-color:  #bbc7e0;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col4 {
#             background-color:  #eee8f3;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col5 {
#             background-color:  #eee9f3;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col7 {
#             background-color:  #e7e3f0;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row0_col9 {
#             background-color:  #e9e5f1;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col0 {
#             background-color:  #023f64;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col1 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col2 {
#             background-color:  #045c90;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col3 {
#             background-color:  #c8cde4;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col4 {
#             background-color:  #eee8f3;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col5 {
#             background-color:  #eee9f3;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col6 {
#             background-color:  #fef6fa;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col7 {
#             background-color:  #e6e2ef;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col8 {
#             background-color:  #fef6fa;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row1_col9 {
#             background-color:  #e7e3f0;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col0 {
#             background-color:  #046299;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col1 {
#             background-color:  #045b8f;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col2 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col3 {
#             background-color:  #e5e1ef;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col4 {
#             background-color:  #f4eef6;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col5 {
#             background-color:  #f4eef6;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col6 {
#             background-color:  #f8f1f8;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col7 {
#             background-color:  #e1dfed;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col8 {
#             background-color:  #f8f1f8;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row2_col9 {
#             background-color:  #e3e0ee;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col0 {
#             background-color:  #dcdaeb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col1 {
#             background-color:  #e7e3f0;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col2 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col3 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col4 {
#             background-color:  #dcdaeb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col5 {
#             background-color:  #e1dfed;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col6 {
#             background-color:  #f6eff7;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col7 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col8 {
#             background-color:  #f8f1f8;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row3_col9 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col0 {
#             background-color:  #e0dded;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col1 {
#             background-color:  #e1dfed;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col2 {
#             background-color:  #ebe6f2;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col3 {
#             background-color:  #a9bfdc;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col4 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col5 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col6 {
#             background-color:  #e5e1ef;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col7 {
#             background-color:  #b4c4df;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col8 {
#             background-color:  #f4edf6;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row4_col9 {
#             background-color:  #d7d6e9;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col0 {
#             background-color:  #e0dded;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col1 {
#             background-color:  #e2dfee;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col2 {
#             background-color:  #ece7f2;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col3 {
#             background-color:  #b0c2de;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col4 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col5 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col6 {
#             background-color:  #f2ecf5;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col7 {
#             background-color:  #d3d4e7;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col8 {
#             background-color:  #e4e1ef;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row5_col9 {
#             background-color:  #b4c4df;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col0 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col1 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col2 {
#             background-color:  #faf3f9;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col3 {
#             background-color:  #dddbec;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col4 {
#             background-color:  #f2ecf5;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col5 {
#             background-color:  #fef6fa;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col6 {
#             background-color:  #023858;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col7 {
#             background-color:  #e0dded;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col8 {
#             background-color:  #99b8d8;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row6_col9 {
#             background-color:  #e3e0ee;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col0 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col1 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col2 {
#             background-color:  #fdf5fa;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col3 {
#             background-color:  #fff7fb;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col4 {
#             background-color:  #e5e1ef;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col5 {
#             background-color:  #faf3f9;
#         }    #T_ef072e3a_3efb_11e9_84db_ecf4bb1392c7row7_col6 {
#             bac

# %%
#the relation ship between flights and seats.
plt.scatter(data_air_no_na["Flights"], data_air_no_na["Distance"], alpha=0.5)
plt.title('The relation_ship between the flights and seats.')
plt.xlabel('The number of flights.')
plt.ylabel('The Distances.')
plt.show()
'''
As we see the graph tells use that there are only less flights presents for the larger distances.Their are many filghts for smaller distances.
so now i want to know why the number of flights is less for larger distances.(i can do it by checking the relation ship between the distance and the passengers.)
'''

# %%
#the relation ship between flights and seats.
plt.scatter(data_air_no_na["Distance"], data_air_no_na["Passengers"], alpha=0.5)
plt.title('The relationship between distance and passengers.')
plt.xlabel('The distance.')
plt.ylabel('The passengers')
plt.show()
#As in the graph belowe showes that at less distance the number of passenger are more ,so we can now infer that as the number of passengers are less to travel long distances the number of flights are also less.
#so the conclusion is the demand is less so number of flights are also less.

# %%
print("hello")
